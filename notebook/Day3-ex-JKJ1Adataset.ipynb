# %%
# Google Driveのマウント
from google.colab import drive
drive.mount('/content/drive/')

# 目的の場所（フォルダ・ディレクトリ）へ移動（各自の環境で適宜修正）
# %cd "/content/drive/MyDrive/Colab Notebooks/JKJ1A/"
# %ls
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/JKJ1A
# backyard/  data/  __init__.py  model/  notebook/  notebook_ans/  src/  src_ans/

# %% [markdown]
# ---
# # 課題１（最終レポート課題）
# Day1, Day2を参考に，自分でJKJ1Aデータセットを用いた課題を設定しそれに取り組め．特にラベルをどのように扱うかに関して工夫せよ．
#
# 課題例：
# - 7次元のヒストグラムの最大だけに注目し，「テスト画像の最大投票を予測する」問題に取り組む．
#
# 次の点が評価の基準となる．
# - どのような問題を設定したか（妥当性・独自性）
# - その問題に対し，正確な実装ができたか・どのような工夫をしたか（技術）
# - 結果に対し良い考察ができているか（思考力）
# - 以上の点をレポートに明快に記述しているか（説明力）
#
# 特に
# - 自分で設定した問題と，Day1, 2の（関係する）問題設定との類似点・相違点（それに対しどう工夫したか）
# - 既存のデータセットとJKJ1Aでどのような性質の違いがあるか（それに対しどう工夫したか）
# - どういう仮説の考え，何が分かったか
#
# など，**実験設定の新規性**と**実験で示した主張**がはっきりわかるようにせよ（そもそもそれがしやすいよう実験課題を設計することも重要）．
#
#
# 備考
# - 実験課題の実装にあたり，今までにないプログラミング上の課題が出ると思う（ロス関数の設計・ラベルの前処理など）．なるべく実験時間内に積極的に質問し解決すること．
# - ネットワークモデルも各自に任せる．ただし，出力層のユニット数の設定に注意せよ．CIFAR10, FMNISTでは10だったが，今回は（問題設定によるが）7になると思う．
