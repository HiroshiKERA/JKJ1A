# %% [markdown]
# # Google Colabって？
#
# Google ColabはGoogleの提供しているクラウド計算環境です．
#
# 「インターネット経由で接続できるパソコン」くらいの認識でいいです．便利ですね．

# %%
1 + 1  # SHIFT + ENTER （シフトキーとエンターキーの同時押し）
# Out:
# 2

# %%
print('hello world')
# Out:
# hello world

# %%
s = 0
for i in range(100):  # 0, 1, ..., 99の和
    s = s + i
print(s)
# Out:
# 4950

# %%
# xが偶数だとx/2，奇数だと3*x+1を計算して返す関数f（本当はもっと単純に書ける）．
def f(x):
    if x % 2 == 0:
        return x / 2
    else: 
        return 3*x + 1

# %%
f(20)  # 表示されない（表示したい場合は print(f(20)) とする）
f(21)  # 最後の行だけ表示される
# Out:
# 64

# %% [markdown]
# # ファイルにアクセスしたい
#
# Google Colabは皆さんのパソコンにあるファイルにアクセスできません（別の計算機なの当然）．
# Google Colabがアクセスできるのは，**Google Drive**にあるファイルです．
#
# Google Driveは「インターネット上の自分専用のフォルダ」くらいの認識でいいです．そこにファイルを保存します．

# %%
# Google Driveをマウント（読み込み）
from google.colab import drive
drive.mount('/content/drive/')

# 上を実行すると，
## (1) リンクが出てくるのでそれをクリック，
##（2）Googleアカウントにログインして認証コードが出てくる，
##（3）コードをコピーして表示されているボックスに貼り付け．

# 目的の場所（フォルダ・ディレクトリ）へ移動（各自の環境で適宜修正）
# %cd "/content/drive/MyDrive/Colab Notebooks/情報工学実験1A/2021/"
# contentフォルダの中のdriveフォルダの中のMyDriveの中の....情報工学実験1Aの中の2021の中に移動している
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/情報工学実験1A/2021

# %%
# %ls  # 現在いるディレクトリ（フォルダ）の中身を表示
# Out:
# data/  model/  notebook/  src/
